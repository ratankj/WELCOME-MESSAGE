# %%
import ftplib

def delete_and_upload_file_to_ftp(ftp_server, ftp_user, ftp_password, local_file_path, remote_file_path):
    try:
        # Connect to the FTP server
        ftp = ftplib.FTP(ftp_server)
        ftp.login(user=ftp_user, passwd=ftp_password)
        print(f"Connected to FTP server: {ftp_server}")
        
        # Try to delete the existing remote file
        try:
            ftp.delete(remote_file_path)
            print(f"Deleted existing file: {remote_file_path}")
        except ftplib.error_perm as e:
            # If the file does not exist, catch the exception and print a message
            print(f"File {remote_file_path} not found on FTP server. Proceeding with upload.")
        
        # Open the local file
        with open(local_file_path, 'rb') as file:
            # Use the storbinary method to upload the file
            ftp.storbinary(f'STOR {remote_file_path}', file)
            print(f"File {local_file_path} uploaded to {remote_file_path}")
        
        # Close the FTP connection
        ftp.quit()
        print("FTP connection closed.")
    
    except ftplib.all_errors as e:
        print(f"FTP error: {e}")

# %%
# Example usage
ftp_server = '10.10.253.10'  # Replace with your FTP server address
ftp_user = 'edf.ratan.jha'      # Replace with your FTP username
ftp_password = 'Gfsdser#$431123'  # Replace with your FTP password
local_file_path = r'C:\Users\Ratan Kumar Jha\Desktop\welcome msg\ANALYSIS OUTPUT\FINAL_DATA\FINAL_DATA_ALL_MERGE_MISSING_DAYS_COUNT.csv'  # Replace with the path to your local CSV file
remote_file_path = '/EDF Code Automation/FINAL_DATA_ALL_MERGE_MISSING_DAYS_COUNT.csv'  # Replace with the desired remote path

delete_and_upload_file_to_ftp(ftp_server, ftp_user, ftp_password, local_file_path, remote_file_path)
# Out:
# Connected to FTP server: 10.10.253.10
# Deleted existing file: /EDF Code Automation/FINAL_DATA_ALL_MERGE_MISSING_DAYS_COUNT.csv
# File C:\Users\Ratan Kumar Jha\Desktop\welcome msg\ANALYSIS OUTPUT\FINAL_DATA\FINAL_DATA_ALL_MERGE_MISSING_DAYS_COUNT.csv uploaded to /EDF Code Automation/FINAL_DATA_ALL_MERGE_MISSING_DAYS_COUNT.csv
# FTP connection closed.

# %%
# Example usage
ftp_server = '10.10.253.10'  # Replace with your FTP server address
ftp_user = 'edf.ratan.jha'      # Replace with your FTP username
ftp_password = 'Gfsdser#$431123'  # Replace with your FTP password
local_file_path = r'C:\Users\Ratan Kumar Jha\Desktop\welcome msg\ANALYSIS OUTPUT\FINAL_DATA\Meter_compiled_Category_last_row.csv'  # Replace with the path to your local CSV file
remote_file_path = '/EDF Code Automation/Meter_compiled_Category_last_row.csv'  # Replace with the desired remote path

delete_and_upload_file_to_ftp(ftp_server, ftp_user, ftp_password, local_file_path, remote_file_path)
# Out:
# Connected to FTP server: 10.10.253.10
# Deleted existing file: /EDF Code Automation/Meter_compiled_Category_last_row.csv
# File C:\Users\Ratan Kumar Jha\Desktop\welcome msg\ANALYSIS OUTPUT\FINAL_DATA\Meter_compiled_Category_last_row.csv uploaded to /EDF Code Automation/Meter_compiled_Category_last_row.csv
# FTP connection closed.

# %%
# Example usage
ftp_server = '10.10.253.10'  # Replace with your FTP server address
ftp_user = 'edf.ratan.jha'      # Replace with your FTP username
ftp_password = 'Gfsdser#$431123'  # Replace with your FTP password
local_file_path = r'C:\Users\Ratan Kumar Jha\Desktop\welcome msg\ANALYSIS OUTPUT\FINAL_DATA\WELCOME_MSG_METER_DATA_FINAL_DATA.csv'  # Replace with the path to your local CSV file
remote_file_path = '/EDF Code Automation/WELCOME_MSG_METER_DATA_FINAL_DATA.csv'  # Replace with the desired remote path

delete_and_upload_file_to_ftp(ftp_server, ftp_user, ftp_password, local_file_path, remote_file_path)
# Out:
# Connected to FTP server: 10.10.253.10
# Deleted existing file: /EDF Code Automation/WELCOME_MSG_METER_DATA_FINAL_DATA.csv
# File C:\Users\Ratan Kumar Jha\Desktop\welcome msg\ANALYSIS OUTPUT\FINAL_DATA\WELCOME_MSG_METER_DATA_FINAL_DATA.csv uploaded to /EDF Code Automation/WELCOME_MSG_METER_DATA_FINAL_DATA.csv
# FTP connection closed.
